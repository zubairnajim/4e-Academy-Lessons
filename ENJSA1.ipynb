# %% [markdown]
# <a href="https://colab.research.google.com/github/zubairnajim/4e-Academy-Lessons/blob/main/ENJSA1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ZOREN
# Veri Cekme

# %%
import yfinance as yf
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import matplotlib as plt
import requests
from bs4 import BeautifulSoup as bs

# %%
ZOREN = yf.download('ZOREN.IS', start = '2022-01-01', end = '2022-12-31')
ZOREN
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2022-01-03  1.68  1.73  1.68   1.72       1.72  38890183
# 2022-01-04  1.73  1.82  1.71   1.75       1.75  79885763
# 2022-01-05  1.74  1.79  1.73   1.76       1.76  47561841
# 2022-01-06  1.75  1.78  1.75   1.75       1.75  22304245
# 2022-01-07  1.76  1.78  1.74   1.76       1.76  24837269
# ...          ...   ...   ...    ...        ...       ...
# 2022-12-26  7.36  7.48  7.22   7.22       7.22  65727839
# 2022-12-27  7.23  7.30  6.95   6.97       6.97  46233969
# 2022-12-28  6.97  6.99  6.45   6.66       6.66  59874223
# 2022-12-29  6.67  7.01  6.66   7.01       7.01  33483452
# 2022-12-30  7.12  7.28  7.04   7.11       7.11  44350698
#
# [252 rows x 6 columns]

# %%
ZOREN.head(10)
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2022-01-03  1.68  1.73  1.68   1.72       1.72  38890183
# 2022-01-04  1.73  1.82  1.71   1.75       1.75  79885763
# 2022-01-05  1.74  1.79  1.73   1.76       1.76  47561841
# 2022-01-06  1.75  1.78  1.75   1.75       1.75  22304245
# 2022-01-07  1.76  1.78  1.74   1.76       1.76  24837269
# 2022-01-10  1.77  1.80  1.76   1.77       1.77  27103719
# 2022-01-11  1.78  1.80  1.76   1.77       1.77  44756508
# 2022-01-12  1.79  1.79  1.76   1.77       1.77  23080807
# 2022-01-13  1.76  1.77  1.73   1.73       1.73  20019664
# 2022-01-14  1.73  1.75  1.72   1.73       1.73  20057427

# %%
ZOREN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2022-01-03 to 2022-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       252 non-null    float64
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Close      252 non-null    float64
#  4   Adj Close  252 non-null    float64
#  5   Volume     252 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB

# %%
ZOREN.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  252.000000  252.000000  252.000000  252.000000  252.000000
# mean     3.193810    3.294087    3.117897    3.200913    3.200913
# std      2.033239    2.109660    1.959055    2.029070    2.029070
# min      1.470000    1.520000    1.440000    1.440000    1.440000
# 25%      1.827500    1.867500    1.807500    1.827500    1.827500
# 50%      2.105000    2.175000    2.070000    2.115000    2.115000
# 75%      4.147500    4.350000    4.045000    4.255000    4.255000
# max      8.870000    8.980000    8.550000    8.780000    8.780000
#
#              Volume
# count  2.520000e+02
# mean   7.835057e+07
# std    7.205738e+07
# min    4.439558e+06
# 25%    3.175076e+07
# 50%    5.302452e+07
# 75%    1.035364e+08
# max    4.089837e+08

# %%
#satir silme 
ZOREN = ZOREN [ZOREN.index > '2022-01-01']
ZOREN
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2022-01-03  1.68  1.73  1.68   1.72       1.72  38890183
# 2022-01-04  1.73  1.82  1.71   1.75       1.75  79885763
# 2022-01-05  1.74  1.79  1.73   1.76       1.76  47561841
# 2022-01-06  1.75  1.78  1.75   1.75       1.75  22304245
# 2022-01-07  1.76  1.78  1.74   1.76       1.76  24837269
# ...          ...   ...   ...    ...        ...       ...
# 2022-12-26  7.36  7.48  7.22   7.22       7.22  65727839
# 2022-12-27  7.23  7.30  6.95   6.97       6.97  46233969
# 2022-12-28  6.97  6.99  6.45   6.66       6.66  59874223
# 2022-12-29  6.67  7.01  6.66   7.01       7.01  33483452
# 2022-12-30  7.12  7.28  7.04   7.11       7.11  44350698
#
# [252 rows x 6 columns]

# %%
#sutun silme 
ZOREN = ZOREN[['Adj Close']]
ZOREN
# Out:
#             Adj Close
# Date
# 2022-01-03       1.72
# 2022-01-04       1.75
# 2022-01-05       1.76
# 2022-01-06       1.75
# 2022-01-07       1.76
# ...               ...
# 2022-12-26       7.22
# 2022-12-27       6.97
# 2022-12-28       6.66
# 2022-12-29       7.01
# 2022-12-30       7.11
#
# [252 rows x 1 columns]

# %%
#isim degistirme
ZOREN.columns = ['Kapanis TRY']
ZOREN
# Out:
#             Kapanis TRY
# Date
# 2022-01-03         1.72
# 2022-01-04         1.75
# 2022-01-05         1.76
# 2022-01-06         1.75
# 2022-01-07         1.76
# ...                 ...
# 2022-12-26         7.22
# 2022-12-27         6.97
# 2022-12-28         6.66
# 2022-12-29         7.01
# 2022-12-30         7.11
#
# [252 rows x 1 columns]

# %%
norm = ZOREN.iloc[0, 0]
ZOREN['Normalize'] = ZOREN['Kapanis TRY']/norm
ZOREN
# Out:
# <ipython-input-202-9b05e07da981>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Kapanis TRY  Normalize
# Date
# 2022-01-03         1.72   1.000000
# 2022-01-04         1.75   1.017442
# 2022-01-05         1.76   1.023256
# 2022-01-06         1.75   1.017442
# 2022-01-07         1.76   1.023256
# ...                 ...        ...
# 2022-12-26         7.22   4.197674
# 2022-12-27         6.97   4.052325
# 2022-12-28         6.66   3.872093
# 2022-12-29         7.01   4.075581
# 2022-12-30         7.11   4.133721
#
# [252 rows x 2 columns]

# %%
ZOREN['Normalize'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
figure1 = px.line(ZOREN, y = ("Normalize"))
figure2 = px.bar(ZOREN, y = ("Normalize"))
figure3 = px.scatter(ZOREN, y = ("Normalize"))
figure1.show()
figure2.show()
figure3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig_1 = px.line(ZOREN, y = ("Normalize"), width = 1000, height = 500, title = ('whatever is meant to be written'), 
        hover_data = {"Normalize" : ':.2f', "Kapanis TRY" : ':.2f'},
        labels = {'Date' : 'Tarih', "Normalize" : 'Bist TRY'})
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ZOREN ['degisim'] = ZOREN['Normalize'].diff(1)
# Out:
# <ipython-input-206-c473b2e9339c>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ZOREN["d_yon"] = ZOREN['degisim'].map (lambda x : 'dusen gun' if x < 0 else 'yukselen gun') 
ZOREN
# Out:
# <ipython-input-207-5a70ee4ddf3e>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Kapanis TRY  Normalize   degisim         d_yon
# Date
# 2022-01-03         1.72   1.000000       NaN  yukselen gun
# 2022-01-04         1.75   1.017442  0.017442  yukselen gun
# 2022-01-05         1.76   1.023256  0.005814  yukselen gun
# 2022-01-06         1.75   1.017442 -0.005814     dusen gun
# 2022-01-07         1.76   1.023256  0.005814  yukselen gun
# ...                 ...        ...       ...           ...
# 2022-12-26         7.22   4.197674 -0.034884     dusen gun
# 2022-12-27         6.97   4.052325 -0.145349     dusen gun
# 2022-12-28         6.66   3.872093 -0.180233     dusen gun
# ...

# %%
ZOREN['degisim%'] = ZOREN['degisim']/ZOREN["Normalize"].shift(1)*100
ZOREN
# Out:
# <ipython-input-208-6ae33feb5de9>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             Kapanis TRY  Normalize   degisim         d_yon  degisim%
# Date
# 2022-01-03         1.72   1.000000       NaN  yukselen gun       NaN
# 2022-01-04         1.75   1.017442  0.017442  yukselen gun  1.744184
# 2022-01-05         1.76   1.023256  0.005814  yukselen gun  0.571428
# 2022-01-06         1.75   1.017442 -0.005814     dusen gun -0.568181
# 2022-01-07         1.76   1.023256  0.005814  yukselen gun  0.571428
# ...                 ...        ...       ...           ...       ...
# 2022-12-26         7.22   4.197674 -0.034884     dusen gun -0.824182
# 2022-12-27         6.97   4.052325 -0.145349     dusen gun -3.462604
# ...

# %%
px.bar(ZOREN, y = "degisim",
       color = "d_yon", color_discrete_map = {'dusen gun' : 'orange', "yukselen gun" : 'navy'})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(ZOREN['degisim%'], nbins = 10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 𝔻ers 2

# %%
Kur = yf.download('TRY=X', start = '2022-01-01', end = '2022-12-31')
Kur = Kur[['Adj Close']]
Kur.columns = ['USD/TRY']
Kur['Normalize USD/TRY'] = Kur['USD/TRY']/Kur.iloc[0, 0]
# Out:
# [*********************100%***********************]  1 of 1 completed
# <ipython-input-211-7e340b088763>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Kur
# Out:
#               USD/TRY  Normalize USD/TRY
# Date
# 2022-01-03  13.356600           1.000000
# 2022-01-04  13.061700           0.977921
# 2022-01-05  13.411500           1.004110
# 2022-01-06  13.688000           1.024812
# 2022-01-07  13.782100           1.031857
# ...               ...                ...
# 2022-12-26  18.623430           1.394324
# 2022-12-27  18.656799           1.396823
# 2022-12-28  18.657000           1.396838
# 2022-12-29  18.693670           1.399583
# 2022-12-30  18.702990           1.400281
#
# [260 rows x 2 columns]

# %%
ZORENK = ZOREN.merge(Kur, left_index = True, right_index = True)
ZORENK
# Out:
#             Kapanis TRY  Normalize   degisim         d_yon  degisim%  \
# Date
# 2022-01-03         1.72   1.000000       NaN  yukselen gun       NaN
# 2022-01-04         1.75   1.017442  0.017442  yukselen gun  1.744184
# 2022-01-05         1.76   1.023256  0.005814  yukselen gun  0.571428
# 2022-01-06         1.75   1.017442 -0.005814     dusen gun -0.568181
# 2022-01-07         1.76   1.023256  0.005814  yukselen gun  0.571428
# ...                 ...        ...       ...           ...       ...
# 2022-12-26         7.22   4.197674 -0.034884     dusen gun -0.824182
# 2022-12-27         6.97   4.052325 -0.145349     dusen gun -3.462604
# 2022-12-28         6.66   3.872093 -0.180233     dusen gun -4.447632
# 2022-12-29         7.01   4.075581  0.203489  yukselen gun  5.255261
# 2022-12-30         7.11   4.133721  0.058139  yukselen gun  1.426532
#
#               USD/TRY  Normalize USD/TRY
# Date
# 2022-01-03  13.356600           1.000000
# 2022-01-04  13.061700           0.977921
# ...

# %%
px.line(ZORENK, y = ['Normalize','Normalize USD/TRY'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x = ZORENK.index, y = ZORENK['Normalize'], name = "Normalize ZOREN"))
fig.add_trace(go.Scatter(x = ZORENK.index, y = ZORENK['Normalize USD/TRY'], name = "Normalize USD/TRY"))
fig.update_layout(title = 'Normalize ZOREN ve Normalize Kur',
                  xaxis_title = 'Tarih', xaxis_dtick = 'M1',
                  yaxis_title = "Kapanis (TRY)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
indirme_listesi = ['ZOREN.IS', 'TRY=X']
veri_2022 = pd.DataFrame()

for i in indirme_listesi:
  data = yf.download(i, start = '2022-01-01', end = '2022-12-31')
  data = data['Adj Close'].rename(i)
  veri_2022 = pd.concat([veri_2022, data], axis = 1)  

veri_2022
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             ZOREN.IS      TRY=X
# 2022-01-03      1.72  13.356600
# 2022-01-04      1.75  13.061700
# 2022-01-05      1.76  13.411500
# 2022-01-06      1.75  13.688000
# 2022-01-07      1.76  13.782100
# ...              ...        ...
# 2022-05-19       NaN  15.956300
# 2022-07-11       NaN  17.271601
# 2022-07-12       NaN  17.344700
# 2022-07-15       NaN  17.464100
# 2022-08-30       NaN  18.180000
#
# [260 rows x 2 columns]

# %%
veri_2022.columns = ['Kapanis (TRY)', 'USD/TRY']
veri_2022 = veri_2022[veri_2022['Kapanis (TRY)']>0]
veri_2022
# Out:
#             Kapanis (TRY)    USD/TRY
# 2022-01-03           1.72  13.356600
# 2022-01-04           1.75  13.061700
# 2022-01-05           1.76  13.411500
# 2022-01-06           1.75  13.688000
# 2022-01-07           1.76  13.782100
# ...                   ...        ...
# 2022-12-26           7.22  18.623430
# 2022-12-27           6.97  18.656799
# 2022-12-28           6.66  18.657000
# 2022-12-29           7.01  18.693670
# 2022-12-30           7.11  18.702990
#
# [252 rows x 2 columns]

# %% [markdown]
# For loop

# %%
indirme_listesi = ['ZOREN.IS', 'TRY=X']
veri_2023 = pd.DataFrame()

for i in indirme_listesi:
  data = yf.download(i, start = '2023-01-01', end = '2023-04-30')
  data = data['Adj Close'].rename(i)
  veri_2023 = pd.concat([veri_2023, data], axis = 1)  

veri_2023
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#             ZOREN.IS      TRY=X
# 2023-01-02      7.18  18.644730
# 2023-01-03      7.05  18.743299
# 2023-01-04      6.71  18.706869
# 2023-01-05      6.37  18.735950
# 2023-01-06      6.35  18.766600
# ...              ...        ...
# 2023-02-09       NaN  18.832359
# 2023-02-10       NaN  18.829700
# 2023-02-13       NaN  18.829760
# 2023-02-14       NaN  18.837460
# 2023-04-21       NaN  19.404261
#
# [85 rows x 2 columns]

# %%
veri_2023.columns = ['Kapanis (TRY)', 'USD/TRY']
veri_2023 = veri_2023[veri_2023['Kapanis (TRY)']>0]
veri_2023
# Out:
#             Kapanis (TRY)    USD/TRY
# 2023-01-02           7.18  18.644730
# 2023-01-03           7.05  18.743299
# 2023-01-04           6.71  18.706869
# 2023-01-05           6.37  18.735950
# 2023-01-06           6.35  18.766600
# ...                   ...        ...
# 2023-04-24           4.82  19.405170
# 2023-04-25           4.54  19.402700
# 2023-04-26           4.47  19.417839
# 2023-04-27           4.56  19.423100
# 2023-04-28           4.43  19.435499
#
# [80 rows x 2 columns]

# %%
veri = pd.concat([veri_2022, veri_2023], axis = 0)
veri
# Out:
#             Kapanis (TRY)    USD/TRY
# 2022-01-03           1.72  13.356600
# 2022-01-04           1.75  13.061700
# 2022-01-05           1.76  13.411500
# 2022-01-06           1.75  13.688000
# 2022-01-07           1.76  13.782100
# ...                   ...        ...
# 2023-04-24           4.82  19.405170
# 2023-04-25           4.54  19.402700
# 2023-04-26           4.47  19.417839
# 2023-04-27           4.56  19.423100
# 2023-04-28           4.43  19.435499
#
# [332 rows x 2 columns]

# %%
veri['Normalize'] = veri['Kapanis (TRY)']/veri.iloc[0, 0]
#veri['Normalize USD/TRY'] = veri['USD/TRY']/veri.iloc[0, 0]
veri['Normalize USD/TRY'] = veri['USD/TRY']/veri.loc[veri.index[0], 'USD/TRY']
veri['degisim'] = veri['Normalize'].diff(1)
veri['d_yon'] = veri['degisim'].map(lambda x: 'dusen gun' if x < 0 else 'yukselen gun')
veri['degisim%'] = (veri['degisim']/veri['Normalize'].shift(1))*100
veri
# Out:
#             Kapanis (TRY)    USD/TRY  Normalize  Normalize USD/TRY   degisim  \
# 2022-01-03           1.72  13.356600   1.000000           1.000000       NaN
# 2022-01-04           1.75  13.061700   1.017442           0.977921  0.017442
# 2022-01-05           1.76  13.411500   1.023256           1.004110  0.005814
# 2022-01-06           1.75  13.688000   1.017442           1.024812 -0.005814
# 2022-01-07           1.76  13.782100   1.023256           1.031857  0.005814
# ...                   ...        ...        ...                ...       ...
# 2023-04-24           4.82  19.405170   2.802326           1.452853 -0.029070
# 2023-04-25           4.54  19.402700   2.639535           1.452668 -0.162791
# 2023-04-26           4.47  19.417839   2.598837           1.453801 -0.040698
# 2023-04-27           4.56  19.423100   2.651163           1.454195  0.052326
# 2023-04-28           4.43  19.435499   2.575581           1.455123 -0.075581
#
#                    d_yon  degisim%
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Bar(x = veri.index, y = veri['Normalize'], name = "Normalize ZOREN"))
fig.add_trace(go.Scatter(x = veri.index, y = veri['Normalize USD/TRY'], name = "Normalize USD/TRY"))
fig.update_layout(title = 'Normalize ZOREN ve Normalize Kur',
                  xaxis_title = 'Tarih', xaxis_dtick = 'M1',
                  yaxis_title = "Kapanis (TRY)")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
veri['ay_yil'] = veri.index.strftime('%Y-%m')
veri
# Out:
#             Kapanis (TRY)    USD/TRY  Normalize  Normalize USD/TRY   degisim  \
# 2022-01-03           1.72  13.356600   1.000000           1.000000       NaN
# 2022-01-04           1.75  13.061700   1.017442           0.977921  0.017442
# 2022-01-05           1.76  13.411500   1.023256           1.004110  0.005814
# 2022-01-06           1.75  13.688000   1.017442           1.024812 -0.005814
# 2022-01-07           1.76  13.782100   1.023256           1.031857  0.005814
# ...                   ...        ...        ...                ...       ...
# 2023-04-24           4.82  19.405170   2.802326           1.452853 -0.029070
# 2023-04-25           4.54  19.402700   2.639535           1.452668 -0.162791
# 2023-04-26           4.47  19.417839   2.598837           1.453801 -0.040698
# 2023-04-27           4.56  19.423100   2.651163           1.454195  0.052326
# 2023-04-28           4.43  19.435499   2.575581           1.455123 -0.075581
#
#                    d_yon  degisim%   ay_yil
# ...

# %%
veri_as = veri.pivot_table(values = ['Kapanis (TRY)', 'USD/TRY'], index = 'ay_yil', aggfunc = 'last')
veri_as
# Out:
#          Kapanis (TRY)    USD/TRY
# ay_yil
# 2022-01           1.70  13.482050
# 2022-02           1.51  14.028840
# 2022-03           1.85  14.651010
# 2022-04           2.07  14.788890
# 2022-05           2.12  16.383499
# 2022-06           1.92  16.628201
# 2022-07           2.08  17.945200
# 2022-08           2.93  18.150261
# 2022-09           3.57  18.497499
# 2022-10           4.73  18.572969
# 2022-11           7.89  18.639900
# 2022-12           7.11  18.702990
# 2023-01           4.97  18.808001
# 2023-02           5.18  18.884199
# 2023-03           4.32  19.175699
# 2023-04           4.43  19.435499

# %%
veri_as['degisim'] = veri_as['Kapanis (TRY)'].diff(1)
veri_as['d_yon'] = veri_as['degisim'].map(lambda x: 'dusen gun' if x < 0 else 'yukselen gun')
veri_as['degisim%'] = (veri_as['degisim']/veri_as['Kapanis (TRY)'].shift(1))
veri_as
# Out:
#          Kapanis (TRY)    USD/TRY  degisim         d_yon  degisim%
# ay_yil
# 2022-01           1.70  13.482050      NaN  yukselen gun       NaN
# 2022-02           1.51  14.028840    -0.19     dusen gun -0.111765
# 2022-03           1.85  14.651010     0.34  yukselen gun  0.225166
# 2022-04           2.07  14.788890     0.22  yukselen gun  0.118919
# 2022-05           2.12  16.383499     0.05  yukselen gun  0.024155
# 2022-06           1.92  16.628201    -0.20     dusen gun -0.094340
# 2022-07           2.08  17.945200     0.16  yukselen gun  0.083333
# 2022-08           2.93  18.150261     0.85  yukselen gun  0.408654
# 2022-09           3.57  18.497499     0.64  yukselen gun  0.218430
# 2022-10           4.73  18.572969     1.16  yukselen gun  0.324930
# 2022-11           7.89  18.639900     3.16  yukselen gun  0.668076
# 2022-12           7.11  18.702990    -0.78     dusen gun -0.098859
# 2023-01           4.97  18.808001    -2.14     dusen gun -0.300985
# ...

# %%
px.bar(veri_as, y = "degisim%",
       color = "d_yon", color_discrete_map = {'dusen gun' : 'red', "yukselen gun" : 'green'},
       text_auto = ".0%")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
veri_as2 = veri.resample('BM', convention = 'end').asfreq()
veri_as2
# Out:
#             Kapanis (TRY)    USD/TRY  Normalize  Normalize USD/TRY   degisim  \
# 2022-01-31           1.70  13.482050   0.988372           1.009392  0.005814
# 2022-02-28           1.51  14.028840   0.877907           1.050330 -0.011628
# 2022-03-31           1.85  14.651010   1.075581           1.096912  0.017442
# 2022-04-29           2.07  14.788890   1.203488           1.107235  0.023256
# 2022-05-31           2.12  16.383499   1.232558           1.226622  0.063953
# 2022-06-30           1.92  16.628201   1.116279           1.244943  0.000000
# 2022-07-29           2.08  17.945200   1.209302           1.343546 -0.023256
# 2022-08-31           2.93  18.150261   1.703488           1.358898 -0.034884
# 2022-09-30           3.57  18.497499   2.075581           1.384896  0.186046
# 2022-10-31           4.73  18.572969   2.750000           1.390546  0.127907
# 2022-11-30           7.89  18.639900   4.587209           1.395557  0.127907
# ...
